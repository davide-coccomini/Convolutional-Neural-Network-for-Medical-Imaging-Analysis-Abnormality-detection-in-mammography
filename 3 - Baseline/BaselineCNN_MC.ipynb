# %% [markdown]
# #Initialization

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
import os
import random
import multiprocessing
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import auc
from sklearn.utils import shuffle

BASE_DIR = '/content/drive/Shareddrives/DeepLearningProject/Coccomini_Gholami_Zara/data/numpy data/'
MODELS_DIR = '/content/drive/Shareddrives/DeepLearningProject/Coccomini_Gholami_Zara/models/MC/'

PUBLIC_TEST_TENSOR = BASE_DIR + 'public_test_tensor.npy'
PUBLIC_TEST_LABELS = BASE_DIR + 'public_test_labels.npy'
PRIVATE_TEST_TENSOR = BASE_DIR + 'private_test_tensor.npy'

TRAIN_LABELS = BASE_DIR + 'train_labels.npy'
TRAIN_TENSOR = BASE_DIR + 'train_tensor.npy'

# training hyperparameters
RESNET_TRAIN_EPOCHS = 200
VGG16_TRAIN_EPOCHS = 50
SCRATCH_TRAIN_EPOCHS = 50
BATCH_SIZE = 16
VERBOSE = 1

RESCALE = 65535

process_manager = multiprocessing.Manager()

final_models_preds = {}
fine_tuned_models_preds = {}

# %%
raw_train_data = np.load(TRAIN_TENSOR).reshape((5352, 150, 150, 1))
raw_train_labels = np.load(TRAIN_LABELS)
raw_test_data = np.load(PUBLIC_TEST_TENSOR).reshape((672, 150, 150, 1))
raw_test_labels = np.load(PUBLIC_TEST_LABELS)

# 0: baseline; 1-2: masses (b-m); 3-4: calcifications (b-m)

# Convert the dataset into a two-class one with only considering "masses" (0) and "calcifications" (1).
def collapse_labels(dataset):
  collapsed_dataset = np.where(dataset < 3, 0, 1)
  return collapsed_dataset


# Datasets without baseline (no class 0)
train_data_no_baseline =  raw_train_data[1::2]
train_labels_no_baseline =  raw_train_labels[1::2]
test_data_no_baseline =  raw_test_data[1::2]
test_labels_no_baseline =  raw_test_labels[1::2]

#copy grayscale channel to channel 2 and 3 because pretrained models work with rgb images
train_data_no_baseline_RGB = np.concatenate((train_data_no_baseline[:], train_data_no_baseline[:], train_data_no_baseline[:]), axis=3);
test_data_no_baseline_RGB = np.concatenate((test_data_no_baseline[:], test_data_no_baseline[:], test_data_no_baseline[:]), axis=3);

# Collapse labels in mass and calcification classes
collapsed_train_labels = collapse_labels(train_labels_no_baseline)
collapsed_test_labels = collapse_labels(test_labels_no_baseline)


# Datasets only baseline (only class 0)
train_data_baseline =  raw_train_data[0::2]
train_labels_baseline =  raw_train_labels[0::2]
test_data_baseline =  raw_test_data[0::2]
test_labels_baseline =  raw_test_labels[0::2]

#copy grayscale channel to channel 2 and 3 because pretrained models work with rgb images
train_data_baseline_RGB = np.concatenate((train_data_baseline[:], train_data_baseline[:], train_data_baseline[:]), axis=3);
test_data_baseline_RGB = np.concatenate((test_data_baseline[:], test_data_baseline[:], test_data_baseline[:]), axis=3);


# no baseline data RGB
train_data_nb_RGB, val_data_nb_RGB, train_labels_nb_RGB, val_labels_nb_RGB = train_test_split(
                                                                    train_data_no_baseline_RGB,
                                                                    collapsed_train_labels,
                                                                    train_size=0.8,
                                                                    random_state=42,
                                                                    shuffle=True
                                                              )

#baseline data RGB
train_data_b_RGB, val_data_b_RGB, train_labels_b_RGB, val_labels_b_RGB = train_test_split(
                                                                    train_data_baseline_RGB,
                                                                    train_labels_baseline,
                                                                    train_size=0.8,
                                                                    random_state=42,
                                                                    shuffle=True
                                                              )
# no baseline data
train_data_nb, val_data_nb, train_labels_nb, val_labels_nb = train_test_split(
                                                                    train_data_no_baseline,
                                                                    collapsed_train_labels,
                                                                    train_size=0.8,
                                                                    random_state=42,
                                                                    shuffle=True
                                                              )

#baseline data
train_data_b, val_data_b, train_labels_b, val_labels_b = train_test_split(
                                                                    train_data_baseline,
                                                                    train_labels_baseline,
                                                                    train_size=0.8,
                                                                    random_state=42,
                                                                    shuffle=True
                                                              )

# %% [markdown]
# ###Data Visualization

# %%
def show_accuracy_loss_trends(fit_results):
  acc = fit_results['accuracy']
  val_acc = fit_results['val_accuracy']
  loss = fit_results['loss']
  val_loss = fit_results['val_loss']

  epochs = range(len(acc))

  plt.figure()
  plt.ylim((0, 1))
  plt.plot(epochs, acc, 'g', label='Training acc')
  plt.plot(epochs, val_acc, 'g--', label='Validation acc')
  plt.plot(epochs, loss, 'r', label='Training loss')
  plt.plot(epochs, val_loss, 'r--', label='Validation loss')
  plt.legend()

  plt.show()

# %%
def show_confusion_matrix(confusion_matrix):
  fig, ax = plt.subplots()
  im = ax.imshow(confusion_matrix, cmap="Blues")

  threshold = im.norm(confusion_matrix.max())/2.
  textcolors=("black", "white")

  ax.set_xticks(np.arange(2))
  ax.set_yticks(np.arange(2))
  ax.set_xticklabels(["mass", "calcification"])
  ax.set_yticklabels(["mass", "calcification"])
  
  ax.tick_params(top=True, bottom=False, labeltop=True, labelbottom=False)

  for i in range(2):
      for j in range(2):
          text = ax.text(j, i, confusion_matrix[i, j], ha="center", va="center", 
                         fontsize=12, color=textcolors[int(im.norm(confusion_matrix[i, j]) > threshold)])

  fig.tight_layout()
  plt.show()

# %%
def show_roc_curves(models_preds):
  plt.figure(1)
  plt.plot([0, 1], [0, 1], 'k--')

  for model, model_preds in models_preds.items():
    fpr,tpr,th = metrics.roc_curve(collapsed_test_labels,model_preds)
    model_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label= model + ' (area = {:.3f})'.format(model_auc))

  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.show()

# %%
def show_generator_images(generator):
  from tensorflow.keras.preprocessing import image

  i = 0
  var = np.asarray(next(generator))
  images = np.asarray(var[0])

  for baseline, abnormality in zip(images[0], images[1]):
      plt.figure(i)
      plt.subplot(121)
      plt.imshow(image.array_to_img(baseline), cmap="gray")
      plt.subplot(122)
      plt.imshow(image.array_to_img(abnormality), cmap="gray")
      i += 1

  plt.show()

# %% [markdown]
# ###Data Augmentation

# %%
# data augmentation hyperparameters
HORIZONTAL_FLIP = True
VERTICAL_FLIP = True
ROTATION_RANGE = 360
FILL_MODE='nearest'

def get_train_datagen(preprocess):
  from tensorflow import keras
  from keras.preprocessing.image import ImageDataGenerator
  return ImageDataGenerator(
        preprocessing_function=preprocess,
        horizontal_flip = HORIZONTAL_FLIP,
        vertical_flip = VERTICAL_FLIP, 
        rotation_range = ROTATION_RANGE,
        fill_mode=FILL_MODE
      )

def get_validation_datagen(preprocess):
  from tensorflow import keras
  from keras.preprocessing.image import ImageDataGenerator
  return ImageDataGenerator(
        preprocessing_function=preprocess
      )



def get_train_generator(baseline_data, baseline_labels, no_baseline_data, no_baseline_labels, preprocess):
  baseline_generator = get_train_datagen(preprocess).flow(baseline_data, baseline_labels, batch_size=BATCH_SIZE, shuffle=True, seed=42)
  abnormality_generator = get_train_datagen(preprocess).flow(no_baseline_data, no_baseline_labels, batch_size=BATCH_SIZE, shuffle=True, seed=42)

  while True:
          baseline = baseline_generator.next()
          abnormality = abnormality_generator.next()
          yield [baseline[0], abnormality[0]], abnormality[1]


def get_validation_generator(baseline_data, baseline_labels, no_baseline_data, no_baseline_labels, preprocess):
  baseline_generator = get_validation_datagen(preprocess).flow(baseline_data, baseline_labels, batch_size=BATCH_SIZE, shuffle=True, seed=42)
  abnormality_generator = get_validation_datagen(preprocess).flow(no_baseline_data, no_baseline_labels, batch_size=BATCH_SIZE, shuffle=True, seed=42)

  while True:
          baseline = baseline_generator.next()
          abnormality = abnormality_generator.next()
          yield [baseline[0], abnormality[0]], abnormality[1]

# %%
def data_augmentation_example():
  train_generator = get_train_generator(train_data_b, train_labels_b, train_data_nb, train_labels_nb, None)

  show_generator_images(train_generator)


p = multiprocessing.Process(target=data_augmentation_example)
p.start()
p.join()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# #Scratch

# %% [markdown]
# ##Model architecture

# %%
def get_siamese_scratch_model():
  from tensorflow import keras
  from keras import layers
  from keras import models
  from keras import regularizers
  from keras import Model

  baseline_input = keras.Input(shape=(150, 150, 1))
  abnormality_input = keras.Input(shape=(150, 150, 1))

  scratch_conv_base = keras.models.Sequential()
  kernel_size = (3,3)
  pool_size= (2,2)
  first_filters = 32
  second_filters = 64
  third_filters = 128

  dropout_conv = 0.3

  reg = regularizers.l1_l2(l1=1e-9, l2=1e-8)
  scratch_conv_base.add(layers.Conv2D(first_filters, kernel_size, activation = 'relu', input_shape = (150, 150, 1)))
  scratch_conv_base.add(layers.Conv2D(first_filters, kernel_size, activation = 'relu'))
  scratch_conv_base.add(layers.Conv2D(first_filters, kernel_size, activation = 'relu'))
  scratch_conv_base.add(layers.MaxPooling2D(pool_size = pool_size)) 

  scratch_conv_base.add(layers.Conv2D(second_filters, kernel_size, activation ='relu'))
  scratch_conv_base.add(layers.Conv2D(second_filters, kernel_size, activation ='relu'))
  scratch_conv_base.add(layers.Conv2D(second_filters, kernel_size, activation ='relu'))
  scratch_conv_base.add(layers.MaxPooling2D(pool_size = pool_size))

  scratch_conv_base.add(layers.Flatten())

  encoded_baseline = scratch_conv_base(baseline_input)
  encoded_abnormality = scratch_conv_base(abnormality_input)

  # Add a customized layer to compute the difference between the encodings
  subtract_layer = keras.layers.Subtract()([encoded_baseline/65535, encoded_abnormality/65535])

  # Add a dense layer with a sigmoid unit to generate the similarity score
  dense_1 = layers.Dense(256,activation='sigmoid')(subtract_layer)
  prediction = layers.Dense(1,activation='sigmoid')(dense_1)

  # Connect the inputs with the outputs
  siamese_model = Model(inputs=[baseline_input, abnormality_input], outputs=prediction)


  ada = keras.optimizers.Adam(learning_rate=0.001)
  # sgd = keras.optimizers.SGD(learning_rate=0.1)
  # rms = keras.optimizers.RMSprop(lr=2e-6)
  siamese_model.compile(loss="binary_crossentropy", optimizer=ada, metrics=['accuracy'])

  return siamese_model

# %% [markdown]
# ##Training and Evaluation

# %%
def scratch_test(scratch_preds):
  if VERBOSE == 1: print("Testing")
  scratch_train_generator = get_train_generator(train_data_b, train_labels_b, train_data_nb, train_labels_nb, None)
  scratch_validation_generator = get_validation_generator(val_data_b, val_labels_b, val_data_nb, val_labels_nb, None)

  final_model = get_siamese_scratch_model()
  fit_results = final_model.fit(
      scratch_train_generator,
      epochs=SCRATCH_TRAIN_EPOCHS,
      steps_per_epoch=int(np.ceil(len(train_data_b) / float(BATCH_SIZE))),
      validation_data=scratch_validation_generator,
      validation_steps=int(np.ceil(len(train_data_b) / float(BATCH_SIZE))),
      verbose=VERBOSE
  )
  
  show_accuracy_loss_trends(fit_results.history)

  preds = final_model.predict([test_data_baseline, test_data_no_baseline])

  for pred in preds:
    scratch_preds.append(pred[0])
  
  final_model.save(os.path.join(MODELS_DIR,'baseline_scratch.h5'))

# %%
preds = process_manager.list()

#execute testing in a secondary process to avoid RAM saturation
p = multiprocessing.Process(target=scratch_test, args=(preds, ))
p.start()
p.join()

preds = np.asarray(preds)

show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
print("\nScratch test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

final_models_preds.update({"scratch": preds})
# Out:
# Testing
# Epoch 1/50
# 134/134 [==============================] - 16s 99ms/step - loss: 0.6843 - accuracy: 0.6018 - val_loss: 0.6616 - val_accuracy: 0.5637
# Epoch 2/50
# 134/134 [==============================] - 12s 90ms/step - loss: 0.6301 - accuracy: 0.6608 - val_loss: 0.5622 - val_accuracy: 0.7259
# Epoch 3/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5950 - accuracy: 0.7103 - val_loss: 0.5388 - val_accuracy: 0.7339
# Epoch 4/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5518 - accuracy: 0.7274 - val_loss: 0.5508 - val_accuracy: 0.7410
# Epoch 5/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5607 - accuracy: 0.7399 - val_loss: 0.5368 - val_accuracy: 0.7486
# Epoch 6/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5487 - accuracy: 0.7377 - val_loss: 0.5514 - val_accuracy: 0.7240
# Epoch 7/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5353 - accuracy: 0.7412 - val_loss: 0.5365 - val_accuracy: 0.7457
# Epoch 8/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5161 - accuracy: 0.7462 - val_loss: 0.5249 - val_accuracy: 0.7462
# Epoch 9/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5418 - accuracy: 0.7371 - val_loss: 0.5607 - val_accuracy: 0.7438
# Epoch 10/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5016 - accuracy: 0.7799 - val_loss: 0.5184 - val_accuracy: 0.7363
# Epoch 11/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5033 - accuracy: 0.7679 - val_loss: 0.5439 - val_accuracy: 0.7225
# Epoch 12/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5282 - accuracy: 0.7546 - val_loss: 0.5250 - val_accuracy: 0.7434
# Epoch 13/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5172 - accuracy: 0.7558 - val_loss: 0.5172 - val_accuracy: 0.7415
# Epoch 14/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5065 - accuracy: 0.7717 - val_loss: 0.5013 - val_accuracy: 0.7599
# Epoch 15/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5285 - accuracy: 0.7595 - val_loss: 0.5259 - val_accuracy: 0.7505
# Epoch 16/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5218 - accuracy: 0.7523 - val_loss: 0.4979 - val_accuracy: 0.7533
# Epoch 17/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5067 - accuracy: 0.7603 - val_loss: 0.5015 - val_accuracy: 0.7576
# Epoch 18/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5115 - accuracy: 0.7591 - val_loss: 0.5183 - val_accuracy: 0.7438
# Epoch 19/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.4879 - accuracy: 0.7841 - val_loss: 0.5160 - val_accuracy: 0.7519
# Epoch 20/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.4724 - accuracy: 0.7858 - val_loss: 0.4900 - val_accuracy: 0.7633
# Epoch 21/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5022 - accuracy: 0.7694 - val_loss: 0.4783 - val_accuracy: 0.7751
# Epoch 22/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5046 - accuracy: 0.7660 - val_loss: 0.4822 - val_accuracy: 0.7779
# Epoch 23/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.4907 - accuracy: 0.7730 - val_loss: 0.4982 - val_accuracy: 0.7618
# Epoch 24/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5014 - accuracy: 0.7531 - val_loss: 0.7981 - val_accuracy: 0.5625
# Epoch 25/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.7134 - accuracy: 0.5582 - val_loss: 0.6583 - val_accuracy: 0.6108
# Epoch 26/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.6343 - accuracy: 0.6403 - val_loss: 0.6223 - val_accuracy: 0.6723
# Epoch 27/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.6248 - accuracy: 0.6529 - val_loss: 0.6325 - val_accuracy: 0.6378
# Epoch 28/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.6187 - accuracy: 0.6598 - val_loss: 0.6115 - val_accuracy: 0.6671
# Epoch 29/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.6038 - accuracy: 0.6818 - val_loss: 0.6044 - val_accuracy: 0.6851
# Epoch 30/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.6039 - accuracy: 0.6792 - val_loss: 0.6184 - val_accuracy: 0.6506
# Epoch 31/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5949 - accuracy: 0.6846 - val_loss: 0.5979 - val_accuracy: 0.6970
# Epoch 32/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5956 - accuracy: 0.6915 - val_loss: 0.5972 - val_accuracy: 0.6823
# Epoch 33/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5933 - accuracy: 0.6862 - val_loss: 0.6050 - val_accuracy: 0.6804
# Epoch 34/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5848 - accuracy: 0.7004 - val_loss: 0.5946 - val_accuracy: 0.6590
# Epoch 35/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5881 - accuracy: 0.6848 - val_loss: 0.5953 - val_accuracy: 0.6821
# Epoch 36/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5937 - accuracy: 0.7096 - val_loss: 0.5899 - val_accuracy: 0.6880
# Epoch 37/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5844 - accuracy: 0.6865 - val_loss: 0.5944 - val_accuracy: 0.7031
# Epoch 38/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5767 - accuracy: 0.7174 - val_loss: 0.5899 - val_accuracy: 0.6813
# Epoch 39/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5778 - accuracy: 0.6997 - val_loss: 0.5869 - val_accuracy: 0.6993
# Epoch 40/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5797 - accuracy: 0.7062 - val_loss: 0.6145 - val_accuracy: 0.6487
# Epoch 41/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5769 - accuracy: 0.7039 - val_loss: 0.5900 - val_accuracy: 0.6847
# Epoch 42/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5816 - accuracy: 0.7099 - val_loss: 0.5859 - val_accuracy: 0.6719
# Epoch 43/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5712 - accuracy: 0.6960 - val_loss: 0.5882 - val_accuracy: 0.6913
# Epoch 44/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5842 - accuracy: 0.6900 - val_loss: 0.5897 - val_accuracy: 0.7008
# Epoch 45/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5655 - accuracy: 0.7285 - val_loss: 0.5960 - val_accuracy: 0.6686
# Epoch 46/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5888 - accuracy: 0.6835 - val_loss: 0.5780 - val_accuracy: 0.7017
# Epoch 47/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5630 - accuracy: 0.7260 - val_loss: 0.5830 - val_accuracy: 0.7003
# Epoch 48/50
# 134/134 [==============================] - 12s 91ms/step - loss: 0.5699 - accuracy: 0.7188 - val_loss: 0.5718 - val_accuracy: 0.6946
# Epoch 49/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5729 - accuracy: 0.7028 - val_loss: 0.5825 - val_accuracy: 0.6955
# Epoch 50/50
# 134/134 [==============================] - 12s 92ms/step - loss: 0.5901 - accuracy: 0.6978 - val_loss: 0.5760 - val_accuracy: 0.6984
# Scratch test accuracy: 0.6696428571428571

# %% [markdown]
# #ResNet50

# %% [markdown]
# ##Model architecture

# %%
def get_siamese_resnet_model():
  from tensorflow import keras
  from keras import layers
  from keras import models
  from keras.applications import ResNet50

  baseline_input = keras.Input(shape=(150, 150, 3))
  abnormality_input = keras.Input(shape=(150, 150, 3))

  ResNet50_conv_base = ResNet50(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
  ResNet50_conv_base.trainable = False

  flatten_layer = layers.Flatten()

  encoded_baseline = flatten_layer(ResNet50_conv_base(baseline_input))
  encoded_abnormality = flatten_layer(ResNet50_conv_base(abnormality_input))

  # Add a customized layer to compute the difference between the encodings
  subtract_layer = keras.layers.Subtract()([encoded_baseline/65535, encoded_abnormality/65535])

  # Add a dense layer with a sigmoid unit to generate the similarity score
  dense_1 = layers.Dense(256,activation='sigmoid')(subtract_layer)
  prediction = layers.Dense(1,activation='sigmoid')(dense_1)

  # Connect the inputs with the outputs
  siamese_model = Model(inputs=[baseline_input, abnormality_input], outputs=prediction)


  ada = keras.optimizers.Adam(learning_rate=0.001)
  # sgd = keras.optimizers.SGD(learning_rate=0.1)
  # rms = keras.optimizers.RMSprop(lr=2e-6)
  siamese_model.compile(loss="binary_crossentropy", optimizer=ada, metrics=['accuracy'])

  return siamese_model

# %% [markdown]
# ##Training and Evaluation

# %%
def resnet_test(resnet_preds):
  if VERBOSE == 1: print("Testing")
  from keras.applications.resnet import preprocess_input as resnet_preprocess

  resnet_train_generator = get_train_generator(train_data_b_RGB, train_labels_b_RGB, train_data_nb_RGB, train_labels_nb_RGB, resnet_preprocess)
  resnet_validation_generator = get_validation_generator(val_data_b_RGB, val_labels_b_RGB, val_data_nb_RGB, val_labels_nb_RGB, resnet_preprocess)

  final_model = get_siamese_resnet_model()
  fit_results = final_model.fit(
      resnet_train_generator,
      epochs=RESNET_TRAIN_EPOCHS,
      steps_per_epoch=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      validation_data=resnet_validation_generator,
      validation_steps=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      verbose=VERBOSE
  )
  
  show_accuracy_loss_trends(fit_results.history)

  preds = final_model.predict([test_data_baseline_RGB, test_data_no_baseline_RGB])

  for pred in preds:
    resnet_preds.append(pred[0])
  
  final_model.save(os.path.join(MODELS_DIR,'baseline_resnet.h5'))

# %%
preds = process_manager.list()

#execute testing in a secondary process to avoid RAM saturation
p = multiprocessing.Process(target=resnet_test, args=(preds, ))
p.start()
p.join()

preds = np.asarray(preds)

show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
print("\nResnet test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

final_models_preds.update({"resnet": preds})
# Out:
# Testing
# Epoch 1/200
# 134/134 [==============================] - 39s 239ms/step - loss: 0.6605 - accuracy: 0.6185 - val_loss: 0.6001 - val_accuracy: 0.6538
# Epoch 2/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.5914 - accuracy: 0.6921 - val_loss: 0.5475 - val_accuracy: 0.7339
# Epoch 3/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.5716 - accuracy: 0.7145 - val_loss: 0.5297 - val_accuracy: 0.7396
# Epoch 4/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.5358 - accuracy: 0.7388 - val_loss: 0.5203 - val_accuracy: 0.7339
# Epoch 5/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.5360 - accuracy: 0.7476 - val_loss: 0.5144 - val_accuracy: 0.7628
# Epoch 6/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.5084 - accuracy: 0.7556 - val_loss: 0.5137 - val_accuracy: 0.7633
# Epoch 7/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.5601 - accuracy: 0.7257 - val_loss: 0.5052 - val_accuracy: 0.7576
# Epoch 8/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.5037 - accuracy: 0.7730 - val_loss: 0.4820 - val_accuracy: 0.7841
# Epoch 9/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.4988 - accuracy: 0.7766 - val_loss: 0.4760 - val_accuracy: 0.7884
# Epoch 10/200
# 134/134 [==============================] - 31s 230ms/step - loss: 0.4795 - accuracy: 0.7917 - val_loss: 0.4749 - val_accuracy: 0.7912
# Epoch 11/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.4766 - accuracy: 0.7913 - val_loss: 0.5050 - val_accuracy: 0.7789
# Epoch 12/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.4988 - accuracy: 0.7827 - val_loss: 0.4859 - val_accuracy: 0.7566
# Epoch 13/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.4839 - accuracy: 0.7657 - val_loss: 0.4731 - val_accuracy: 0.7865
# Epoch 14/200
# 134/134 [==============================] - 31s 229ms/step - loss: 0.4733 - accuracy: 0.7783 - val_loss: 0.4680 - val_accuracy: 0.7988
# Epoch 15/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.4747 - accuracy: 0.7833 - val_loss: 0.4493 - val_accuracy: 0.7988
# Epoch 16/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.4805 - accuracy: 0.7896 - val_loss: 0.4545 - val_accuracy: 0.8054
# Epoch 17/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4717 - accuracy: 0.8018 - val_loss: 0.4650 - val_accuracy: 0.7959
# Epoch 18/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4820 - accuracy: 0.7908 - val_loss: 0.4650 - val_accuracy: 0.7865
# Epoch 19/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4680 - accuracy: 0.7990 - val_loss: 0.4590 - val_accuracy: 0.7917
# Epoch 20/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4392 - accuracy: 0.7995 - val_loss: 0.4570 - val_accuracy: 0.7983
# Epoch 21/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4731 - accuracy: 0.7872 - val_loss: 0.4510 - val_accuracy: 0.8002
# Epoch 22/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.4849 - accuracy: 0.7807 - val_loss: 0.4417 - val_accuracy: 0.8040
# Epoch 23/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4432 - accuracy: 0.7988 - val_loss: 0.4619 - val_accuracy: 0.7997
# Epoch 24/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4647 - accuracy: 0.7936 - val_loss: 0.4409 - val_accuracy: 0.8030
# Epoch 25/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.4488 - accuracy: 0.8102 - val_loss: 0.4432 - val_accuracy: 0.8168
# Epoch 26/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4563 - accuracy: 0.7934 - val_loss: 0.4433 - val_accuracy: 0.8030
# Epoch 27/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4592 - accuracy: 0.7933 - val_loss: 0.4364 - val_accuracy: 0.8097
# Epoch 28/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4524 - accuracy: 0.7966 - val_loss: 0.4382 - val_accuracy: 0.8078
# Epoch 29/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4155 - accuracy: 0.8254 - val_loss: 0.4410 - val_accuracy: 0.7964
# Epoch 30/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4573 - accuracy: 0.8093 - val_loss: 0.4479 - val_accuracy: 0.8087
# Epoch 31/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4521 - accuracy: 0.8080 - val_loss: 0.4306 - val_accuracy: 0.8120
# Epoch 32/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4336 - accuracy: 0.8049 - val_loss: 0.4437 - val_accuracy: 0.8134
# Epoch 33/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4220 - accuracy: 0.8176 - val_loss: 0.4314 - val_accuracy: 0.8101
# Epoch 34/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4260 - accuracy: 0.8135 - val_loss: 0.4530 - val_accuracy: 0.8028
# Epoch 35/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4554 - accuracy: 0.8035 - val_loss: 0.4659 - val_accuracy: 0.8038
# Epoch 36/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4255 - accuracy: 0.8219 - val_loss: 0.4354 - val_accuracy: 0.8045
# Epoch 37/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4359 - accuracy: 0.8175 - val_loss: 0.4347 - val_accuracy: 0.8021
# Epoch 38/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4324 - accuracy: 0.8191 - val_loss: 0.4337 - val_accuracy: 0.8149
# Epoch 39/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4417 - accuracy: 0.8120 - val_loss: 0.4246 - val_accuracy: 0.8092
# Epoch 40/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4312 - accuracy: 0.8198 - val_loss: 0.4324 - val_accuracy: 0.7978
# Epoch 41/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4109 - accuracy: 0.8234 - val_loss: 0.4307 - val_accuracy: 0.8196
# Epoch 42/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4140 - accuracy: 0.8311 - val_loss: 0.4219 - val_accuracy: 0.8168
# Epoch 43/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4245 - accuracy: 0.8246 - val_loss: 0.4380 - val_accuracy: 0.8106
# Epoch 44/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4180 - accuracy: 0.8139 - val_loss: 0.4310 - val_accuracy: 0.8045
# Epoch 45/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4386 - accuracy: 0.8120 - val_loss: 0.4503 - val_accuracy: 0.8106
# Epoch 46/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4360 - accuracy: 0.8151 - val_loss: 0.4162 - val_accuracy: 0.8205
# Epoch 47/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4101 - accuracy: 0.8298 - val_loss: 0.4213 - val_accuracy: 0.8191
# Epoch 48/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4027 - accuracy: 0.8373 - val_loss: 0.4288 - val_accuracy: 0.8130
# Epoch 49/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4983 - accuracy: 0.7585 - val_loss: 0.4190 - val_accuracy: 0.8277
# Epoch 50/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4112 - accuracy: 0.8102 - val_loss: 0.4168 - val_accuracy: 0.8106
# Epoch 51/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4126 - accuracy: 0.8345 - val_loss: 0.4164 - val_accuracy: 0.8177
# Epoch 52/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4187 - accuracy: 0.8101 - val_loss: 0.4112 - val_accuracy: 0.8163
# Epoch 53/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4115 - accuracy: 0.8171 - val_loss: 0.4369 - val_accuracy: 0.8026
# Epoch 54/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4296 - accuracy: 0.8175 - val_loss: 0.4194 - val_accuracy: 0.8205
# Epoch 55/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4177 - accuracy: 0.8250 - val_loss: 0.4308 - val_accuracy: 0.8229
# Epoch 56/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4277 - accuracy: 0.8306 - val_loss: 0.4524 - val_accuracy: 0.8125
# Epoch 57/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4057 - accuracy: 0.8231 - val_loss: 0.4081 - val_accuracy: 0.8253
# Epoch 58/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3941 - accuracy: 0.8401 - val_loss: 0.4226 - val_accuracy: 0.8163
# Epoch 59/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4786 - accuracy: 0.7722 - val_loss: 0.4006 - val_accuracy: 0.8281
# Epoch 60/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4262 - accuracy: 0.8178 - val_loss: 0.4192 - val_accuracy: 0.8239
# Epoch 61/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4068 - accuracy: 0.8294 - val_loss: 0.4011 - val_accuracy: 0.8338
# Epoch 62/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4287 - accuracy: 0.8166 - val_loss: 0.3983 - val_accuracy: 0.8168
# Epoch 63/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3909 - accuracy: 0.8339 - val_loss: 0.4080 - val_accuracy: 0.8224
# Epoch 64/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3787 - accuracy: 0.8450 - val_loss: 0.4246 - val_accuracy: 0.8182
# Epoch 65/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4067 - accuracy: 0.8373 - val_loss: 0.4106 - val_accuracy: 0.8234
# Epoch 66/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4051 - accuracy: 0.8207 - val_loss: 0.4265 - val_accuracy: 0.8106
# Epoch 67/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3864 - accuracy: 0.8366 - val_loss: 0.4054 - val_accuracy: 0.8163
# Epoch 68/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3683 - accuracy: 0.8473 - val_loss: 0.4011 - val_accuracy: 0.8156
# Epoch 69/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3996 - accuracy: 0.8315 - val_loss: 0.3970 - val_accuracy: 0.8283
# Epoch 70/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3760 - accuracy: 0.8320 - val_loss: 0.4128 - val_accuracy: 0.8305
# Epoch 71/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4778 - accuracy: 0.7801 - val_loss: 0.4018 - val_accuracy: 0.8329
# Epoch 72/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3906 - accuracy: 0.8349 - val_loss: 0.4178 - val_accuracy: 0.8106
# Epoch 73/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3954 - accuracy: 0.8483 - val_loss: 0.4041 - val_accuracy: 0.8348
# Epoch 74/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4036 - accuracy: 0.8257 - val_loss: 0.4052 - val_accuracy: 0.8395
# Epoch 75/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4050 - accuracy: 0.8224 - val_loss: 0.3934 - val_accuracy: 0.8390
# Epoch 76/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4107 - accuracy: 0.8308 - val_loss: 0.4154 - val_accuracy: 0.8243
# Epoch 77/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.4166 - accuracy: 0.8184 - val_loss: 0.3919 - val_accuracy: 0.8423
# Epoch 78/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3729 - accuracy: 0.8358 - val_loss: 0.4054 - val_accuracy: 0.8220
# Epoch 79/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3828 - accuracy: 0.8280 - val_loss: 0.3947 - val_accuracy: 0.8376
# Epoch 80/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3860 - accuracy: 0.8354 - val_loss: 0.3986 - val_accuracy: 0.8348
# Epoch 81/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4001 - accuracy: 0.8223 - val_loss: 0.4183 - val_accuracy: 0.8314
# Epoch 82/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3750 - accuracy: 0.8464 - val_loss: 0.4028 - val_accuracy: 0.8352
# Epoch 83/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4079 - accuracy: 0.8198 - val_loss: 0.3948 - val_accuracy: 0.8362
# Epoch 84/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4484 - accuracy: 0.7794 - val_loss: 0.4087 - val_accuracy: 0.8168
# Epoch 85/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3975 - accuracy: 0.8329 - val_loss: 0.3819 - val_accuracy: 0.8400
# Epoch 86/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3881 - accuracy: 0.8295 - val_loss: 0.3813 - val_accuracy: 0.8376
# Epoch 87/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3780 - accuracy: 0.8395 - val_loss: 0.3927 - val_accuracy: 0.8419
# Epoch 88/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3685 - accuracy: 0.8559 - val_loss: 0.4093 - val_accuracy: 0.8087
# Epoch 89/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3904 - accuracy: 0.8347 - val_loss: 0.3971 - val_accuracy: 0.8385
# Epoch 90/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3791 - accuracy: 0.8312 - val_loss: 0.4030 - val_accuracy: 0.8404
# Epoch 91/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3812 - accuracy: 0.8375 - val_loss: 0.4149 - val_accuracy: 0.8243
# Epoch 92/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3617 - accuracy: 0.8503 - val_loss: 0.4117 - val_accuracy: 0.8314
# Epoch 93/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3922 - accuracy: 0.8131 - val_loss: 0.3946 - val_accuracy: 0.8324
# Epoch 94/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3765 - accuracy: 0.8466 - val_loss: 0.4092 - val_accuracy: 0.8333
# Epoch 95/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3647 - accuracy: 0.8486 - val_loss: 0.4112 - val_accuracy: 0.8229
# Epoch 96/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3774 - accuracy: 0.8473 - val_loss: 0.3817 - val_accuracy: 0.8442
# Epoch 97/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.4049 - accuracy: 0.8245 - val_loss: 0.4204 - val_accuracy: 0.8239
# Epoch 98/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3547 - accuracy: 0.8553 - val_loss: 0.4133 - val_accuracy: 0.8348
# Epoch 99/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3888 - accuracy: 0.8287 - val_loss: 0.4036 - val_accuracy: 0.8333
# Epoch 100/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3681 - accuracy: 0.8501 - val_loss: 0.3916 - val_accuracy: 0.8509
# Epoch 101/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3655 - accuracy: 0.8549 - val_loss: 0.3986 - val_accuracy: 0.8295
# Epoch 102/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3818 - accuracy: 0.8472 - val_loss: 0.4234 - val_accuracy: 0.8057
# Epoch 103/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3965 - accuracy: 0.8319 - val_loss: 0.3925 - val_accuracy: 0.8396
# Epoch 104/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3593 - accuracy: 0.8464 - val_loss: 0.3927 - val_accuracy: 0.8348
# Epoch 105/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3658 - accuracy: 0.8404 - val_loss: 0.4208 - val_accuracy: 0.8234
# Epoch 106/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4377 - accuracy: 0.8074 - val_loss: 0.4580 - val_accuracy: 0.8011
# Epoch 107/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4015 - accuracy: 0.8248 - val_loss: 0.4068 - val_accuracy: 0.8362
# Epoch 108/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3782 - accuracy: 0.8465 - val_loss: 0.3960 - val_accuracy: 0.8338
# Epoch 109/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3892 - accuracy: 0.8478 - val_loss: 0.3919 - val_accuracy: 0.8438
# Epoch 110/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3806 - accuracy: 0.8350 - val_loss: 0.3825 - val_accuracy: 0.8504
# Epoch 111/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3793 - accuracy: 0.8454 - val_loss: 0.4073 - val_accuracy: 0.8277
# Epoch 112/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3682 - accuracy: 0.8515 - val_loss: 0.3863 - val_accuracy: 0.8423
# Epoch 113/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3594 - accuracy: 0.8472 - val_loss: 0.4233 - val_accuracy: 0.8286
# Epoch 114/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3572 - accuracy: 0.8616 - val_loss: 0.4013 - val_accuracy: 0.8305
# Epoch 115/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.4321 - accuracy: 0.8064 - val_loss: 0.4078 - val_accuracy: 0.8300
# Epoch 116/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3718 - accuracy: 0.8450 - val_loss: 0.3928 - val_accuracy: 0.8428
# Epoch 117/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3615 - accuracy: 0.8433 - val_loss: 0.3796 - val_accuracy: 0.8286
# Epoch 118/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3724 - accuracy: 0.8438 - val_loss: 0.3819 - val_accuracy: 0.8466
# Epoch 119/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3549 - accuracy: 0.8569 - val_loss: 0.3827 - val_accuracy: 0.8461
# Epoch 120/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3783 - accuracy: 0.8390 - val_loss: 0.3872 - val_accuracy: 0.8324
# Epoch 121/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3684 - accuracy: 0.8420 - val_loss: 0.4136 - val_accuracy: 0.8286
# Epoch 122/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3768 - accuracy: 0.8387 - val_loss: 0.4088 - val_accuracy: 0.8305
# Epoch 123/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3894 - accuracy: 0.8388 - val_loss: 0.3890 - val_accuracy: 0.8343
# Epoch 124/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3693 - accuracy: 0.8537 - val_loss: 0.3946 - val_accuracy: 0.8461
# Epoch 125/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3548 - accuracy: 0.8477 - val_loss: 0.4072 - val_accuracy: 0.8272
# Epoch 126/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3708 - accuracy: 0.8435 - val_loss: 0.3944 - val_accuracy: 0.8295
# Epoch 127/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3670 - accuracy: 0.8454 - val_loss: 0.3888 - val_accuracy: 0.8414
# Epoch 128/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3757 - accuracy: 0.8411 - val_loss: 0.4066 - val_accuracy: 0.8343
# Epoch 129/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3809 - accuracy: 0.8353 - val_loss: 0.3737 - val_accuracy: 0.8409
# Epoch 130/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3951 - accuracy: 0.8246 - val_loss: 0.3948 - val_accuracy: 0.8243
# Epoch 131/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3715 - accuracy: 0.8376 - val_loss: 0.3928 - val_accuracy: 0.8224
# Epoch 132/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3645 - accuracy: 0.8428 - val_loss: 0.3827 - val_accuracy: 0.8561
# Epoch 133/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3459 - accuracy: 0.8686 - val_loss: 0.3787 - val_accuracy: 0.8385
# Epoch 134/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3498 - accuracy: 0.8556 - val_loss: 0.4030 - val_accuracy: 0.8314
# Epoch 135/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3866 - accuracy: 0.8456 - val_loss: 0.3970 - val_accuracy: 0.8338
# Epoch 136/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3499 - accuracy: 0.8549 - val_loss: 0.3971 - val_accuracy: 0.8208
# Epoch 137/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3427 - accuracy: 0.8551 - val_loss: 0.4074 - val_accuracy: 0.8278
# Epoch 138/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3433 - accuracy: 0.8523 - val_loss: 0.3843 - val_accuracy: 0.8438
# Epoch 139/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3725 - accuracy: 0.8379 - val_loss: 0.4013 - val_accuracy: 0.8281
# Epoch 140/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3670 - accuracy: 0.8417 - val_loss: 0.3985 - val_accuracy: 0.8352
# Epoch 141/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3404 - accuracy: 0.8578 - val_loss: 0.4008 - val_accuracy: 0.8381
# Epoch 142/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3544 - accuracy: 0.8546 - val_loss: 0.3827 - val_accuracy: 0.8471
# Epoch 143/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3650 - accuracy: 0.8500 - val_loss: 0.3934 - val_accuracy: 0.8295
# Epoch 144/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3371 - accuracy: 0.8592 - val_loss: 0.3926 - val_accuracy: 0.8366
# Epoch 145/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3668 - accuracy: 0.8501 - val_loss: 0.4022 - val_accuracy: 0.8329
# Epoch 146/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3708 - accuracy: 0.8435 - val_loss: 0.3763 - val_accuracy: 0.8376
# Epoch 147/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3570 - accuracy: 0.8455 - val_loss: 0.3809 - val_accuracy: 0.8338
# Epoch 148/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3496 - accuracy: 0.8514 - val_loss: 0.3889 - val_accuracy: 0.8442
# Epoch 149/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3632 - accuracy: 0.8432 - val_loss: 0.3899 - val_accuracy: 0.8324
# Epoch 150/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3633 - accuracy: 0.8493 - val_loss: 0.3748 - val_accuracy: 0.8509
# Epoch 151/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3592 - accuracy: 0.8560 - val_loss: 0.4012 - val_accuracy: 0.8305
# Epoch 152/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.4235 - accuracy: 0.8045 - val_loss: 0.3853 - val_accuracy: 0.8433
# Epoch 153/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3660 - accuracy: 0.8531 - val_loss: 0.3738 - val_accuracy: 0.8456
# Epoch 154/200
# 134/134 [==============================] - 29s 220ms/step - loss: 0.3555 - accuracy: 0.8468 - val_loss: 0.3965 - val_accuracy: 0.8333
# Epoch 155/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3328 - accuracy: 0.8578 - val_loss: 0.3757 - val_accuracy: 0.8357
# Epoch 156/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3594 - accuracy: 0.8483 - val_loss: 0.3923 - val_accuracy: 0.8390
# Epoch 157/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3533 - accuracy: 0.8488 - val_loss: 0.3773 - val_accuracy: 0.8395
# Epoch 158/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3337 - accuracy: 0.8493 - val_loss: 0.3792 - val_accuracy: 0.8419
# Epoch 159/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3509 - accuracy: 0.8608 - val_loss: 0.3864 - val_accuracy: 0.8390
# Epoch 160/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3410 - accuracy: 0.8564 - val_loss: 0.3870 - val_accuracy: 0.8409
# Epoch 161/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3532 - accuracy: 0.8514 - val_loss: 0.3776 - val_accuracy: 0.8423
# Epoch 162/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3219 - accuracy: 0.8762 - val_loss: 0.3877 - val_accuracy: 0.8333
# Epoch 163/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3599 - accuracy: 0.8477 - val_loss: 0.3893 - val_accuracy: 0.8291
# Epoch 164/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3391 - accuracy: 0.8635 - val_loss: 0.4176 - val_accuracy: 0.8277
# Epoch 165/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3323 - accuracy: 0.8621 - val_loss: 0.3882 - val_accuracy: 0.8300
# Epoch 166/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3336 - accuracy: 0.8612 - val_loss: 0.3747 - val_accuracy: 0.8343
# Epoch 167/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3362 - accuracy: 0.8571 - val_loss: 0.3616 - val_accuracy: 0.8409
# Epoch 168/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3599 - accuracy: 0.8486 - val_loss: 0.4071 - val_accuracy: 0.8286
# Epoch 169/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3546 - accuracy: 0.8455 - val_loss: 0.3825 - val_accuracy: 0.8400
# Epoch 170/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3498 - accuracy: 0.8506 - val_loss: 0.3881 - val_accuracy: 0.8307
# Epoch 171/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3547 - accuracy: 0.8452 - val_loss: 0.3843 - val_accuracy: 0.8429
# Epoch 172/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3615 - accuracy: 0.8431 - val_loss: 0.3696 - val_accuracy: 0.8461
# Epoch 173/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3371 - accuracy: 0.8503 - val_loss: 0.3966 - val_accuracy: 0.8348
# Epoch 174/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3555 - accuracy: 0.8525 - val_loss: 0.3871 - val_accuracy: 0.8456
# Epoch 175/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3319 - accuracy: 0.8607 - val_loss: 0.4082 - val_accuracy: 0.8305
# Epoch 176/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3429 - accuracy: 0.8594 - val_loss: 0.3880 - val_accuracy: 0.8480
# Epoch 177/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3656 - accuracy: 0.8257 - val_loss: 0.3860 - val_accuracy: 0.8333
# Epoch 178/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3428 - accuracy: 0.8466 - val_loss: 0.3707 - val_accuracy: 0.8452
# Epoch 179/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3514 - accuracy: 0.8539 - val_loss: 0.3830 - val_accuracy: 0.8319
# Epoch 180/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3401 - accuracy: 0.8480 - val_loss: 0.3816 - val_accuracy: 0.8452
# Epoch 181/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3422 - accuracy: 0.8544 - val_loss: 0.4010 - val_accuracy: 0.8352
# Epoch 182/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3436 - accuracy: 0.8708 - val_loss: 0.3914 - val_accuracy: 0.8319
# Epoch 183/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3556 - accuracy: 0.8486 - val_loss: 0.3892 - val_accuracy: 0.8513
# Epoch 184/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3304 - accuracy: 0.8610 - val_loss: 0.3872 - val_accuracy: 0.8438
# Epoch 185/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3537 - accuracy: 0.8598 - val_loss: 0.3766 - val_accuracy: 0.8471
# Epoch 186/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3618 - accuracy: 0.8559 - val_loss: 0.3951 - val_accuracy: 0.8390
# Epoch 187/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3246 - accuracy: 0.8593 - val_loss: 0.3837 - val_accuracy: 0.8518
# Epoch 188/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3506 - accuracy: 0.8521 - val_loss: 0.3688 - val_accuracy: 0.8466
# Epoch 189/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3641 - accuracy: 0.8434 - val_loss: 0.4022 - val_accuracy: 0.8310
# Epoch 190/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3563 - accuracy: 0.8476 - val_loss: 0.3993 - val_accuracy: 0.8338
# Epoch 191/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3359 - accuracy: 0.8473 - val_loss: 0.3999 - val_accuracy: 0.8324
# Epoch 192/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3573 - accuracy: 0.8475 - val_loss: 0.4013 - val_accuracy: 0.8371
# Epoch 193/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3473 - accuracy: 0.8488 - val_loss: 0.3906 - val_accuracy: 0.8376
# Epoch 194/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3360 - accuracy: 0.8543 - val_loss: 0.3941 - val_accuracy: 0.8419
# Epoch 195/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3577 - accuracy: 0.8525 - val_loss: 0.4034 - val_accuracy: 0.8352
# Epoch 196/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3506 - accuracy: 0.8597 - val_loss: 0.4340 - val_accuracy: 0.8215
# Epoch 197/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3398 - accuracy: 0.8542 - val_loss: 0.3729 - val_accuracy: 0.8423
# Epoch 198/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3503 - accuracy: 0.8443 - val_loss: 0.3900 - val_accuracy: 0.8343
# Epoch 199/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3362 - accuracy: 0.8616 - val_loss: 0.3652 - val_accuracy: 0.8400
# Epoch 200/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3453 - accuracy: 0.8577 - val_loss: 0.3753 - val_accuracy: 0.8485
# Resnet test accuracy: 0.8422619047619048

# %% [markdown]
# #VGG16

# %% [markdown]
# ##Model architecture

# %%
def get_siamese_vgg16_model():
  from tensorflow import keras
  from keras import layers
  from keras import models
  from keras.applications import VGG16
  from keras import Model

  baseline_input = keras.Input(shape=(150, 150, 3))
  abnormality_input = keras.Input(shape=(150, 150, 3))

  VGG16_conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
  VGG16_conv_base.trainable = False

  flatten_layer = layers.Flatten()

  encoded_baseline = flatten_layer(VGG16_conv_base(baseline_input))
  encoded_abnormality = flatten_layer(VGG16_conv_base(abnormality_input))

  # Add a customized layer to compute the difference between the encodings
  subtract_layer = keras.layers.Subtract()([encoded_baseline/65535, encoded_abnormality/65535])

  # Add a dense layer with a sigmoid unit to generate the similarity score
  dense_1 = layers.Dense(256,activation='sigmoid')(subtract_layer)
  prediction = layers.Dense(1,activation='sigmoid')(dense_1)

  # Connect the inputs with the outputs
  siamese_model = Model(inputs=[baseline_input, abnormality_input], outputs=prediction)


  ada = keras.optimizers.Adam(learning_rate=0.001)
  # sgd = keras.optimizers.SGD(learning_rate=0.1)
  # rms = keras.optimizers.RMSprop(lr=2e-6)
  siamese_model.compile(loss="binary_crossentropy", optimizer=ada, metrics=['accuracy'])

  return siamese_model

# %% [markdown]
# ##Training and Evaluation

# %%
def vgg16_test(vgg16_preds):
  if VERBOSE == 1: print("Testing")
  from keras.applications.vgg16 import preprocess_input as vgg16_preprocess

  vgg16_train_generator = get_train_generator(train_data_b_RGB, train_labels_b_RGB, train_data_nb_RGB, train_labels_nb_RGB, vgg16_preprocess)
  vgg16_validation_generator = get_validation_generator(val_data_b_RGB, val_labels_b_RGB, val_data_nb_RGB, val_labels_nb_RGB, vgg16_preprocess)

  final_model = get_siamese_vgg16_model()
  fit_results = final_model.fit(
      vgg16_train_generator,
      epochs=VGG16_TRAIN_EPOCHS,
      steps_per_epoch=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      validation_data=vgg16_validation_generator,
      validation_steps=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      verbose=VERBOSE
  )
  
  show_accuracy_loss_trends(fit_results.history)

  preds = final_model.predict([test_data_baseline_RGB, test_data_no_baseline_RGB])

  for pred in preds:
    vgg16_preds.append(pred[0])
  
  final_model.save(os.path.join(MODELS_DIR,'baseline_vgg16.h5'))

# %%
preds = process_manager.list()

#execute testing in a secondary process to avoid RAM saturation
p = multiprocessing.Process(target=vgg16_test, args=(preds, ))
p.start()
p.join()

preds = np.asarray(preds)

show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
print("\nVgg16 test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

final_models_preds.update({"vgg16": preds})
# Out:
# Testing
# Epoch 1/50
# 134/134 [==============================] - 36s 242ms/step - loss: 0.6317 - accuracy: 0.6288 - val_loss: 0.5591 - val_accuracy: 0.6472
# Epoch 2/50
# 134/134 [==============================] - 31s 231ms/step - loss: 0.5173 - accuracy: 0.7627 - val_loss: 0.5108 - val_accuracy: 0.7779
# Epoch 3/50
# 134/134 [==============================] - 32s 239ms/step - loss: 0.4685 - accuracy: 0.7941 - val_loss: 0.4876 - val_accuracy: 0.8063
# Epoch 4/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.4327 - accuracy: 0.8126 - val_loss: 0.4876 - val_accuracy: 0.7708
# Epoch 5/50
# 134/134 [==============================] - 32s 236ms/step - loss: 0.4212 - accuracy: 0.8102 - val_loss: 0.4708 - val_accuracy: 0.8068
# Epoch 6/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3889 - accuracy: 0.8218 - val_loss: 0.4632 - val_accuracy: 0.7931
# Epoch 7/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.4185 - accuracy: 0.8254 - val_loss: 0.4643 - val_accuracy: 0.8078
# Epoch 8/50
# 134/134 [==============================] - 32s 236ms/step - loss: 0.3898 - accuracy: 0.8321 - val_loss: 0.4486 - val_accuracy: 0.8196
# Epoch 9/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3916 - accuracy: 0.8292 - val_loss: 0.4393 - val_accuracy: 0.8239
# Epoch 10/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3795 - accuracy: 0.8442 - val_loss: 0.4433 - val_accuracy: 0.8229
# Epoch 11/50
# 134/134 [==============================] - 32s 236ms/step - loss: 0.3800 - accuracy: 0.8369 - val_loss: 0.4627 - val_accuracy: 0.7988
# Epoch 12/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3914 - accuracy: 0.8194 - val_loss: 0.4524 - val_accuracy: 0.7884
# Epoch 13/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3982 - accuracy: 0.8289 - val_loss: 0.4464 - val_accuracy: 0.8073
# Epoch 14/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3625 - accuracy: 0.8397 - val_loss: 0.4344 - val_accuracy: 0.8097
# Epoch 15/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3602 - accuracy: 0.8501 - val_loss: 0.4259 - val_accuracy: 0.8390
# Epoch 16/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3877 - accuracy: 0.8335 - val_loss: 0.4248 - val_accuracy: 0.8419
# Epoch 17/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3454 - accuracy: 0.8648 - val_loss: 0.4325 - val_accuracy: 0.8319
# Epoch 18/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3930 - accuracy: 0.8352 - val_loss: 0.4219 - val_accuracy: 0.8485
# Epoch 19/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3564 - accuracy: 0.8422 - val_loss: 0.4231 - val_accuracy: 0.8295
# Epoch 20/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3358 - accuracy: 0.8687 - val_loss: 0.4214 - val_accuracy: 0.8267
# Epoch 21/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3461 - accuracy: 0.8451 - val_loss: 0.4312 - val_accuracy: 0.8262
# Epoch 22/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3528 - accuracy: 0.8459 - val_loss: 0.4265 - val_accuracy: 0.8324
# Epoch 23/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3489 - accuracy: 0.8502 - val_loss: 0.4398 - val_accuracy: 0.8267
# Epoch 24/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3569 - accuracy: 0.8477 - val_loss: 0.4248 - val_accuracy: 0.8281
# Epoch 25/50
# 134/134 [==============================] - 31s 233ms/step - loss: 0.3779 - accuracy: 0.8324 - val_loss: 0.4320 - val_accuracy: 0.8215
# Epoch 26/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3633 - accuracy: 0.8562 - val_loss: 0.4440 - val_accuracy: 0.8177
# Epoch 27/50
# 134/134 [==============================] - 31s 234ms/step - loss: 0.3476 - accuracy: 0.8524 - val_loss: 0.4291 - val_accuracy: 0.8224
# Epoch 28/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3685 - accuracy: 0.8381 - val_loss: 0.4256 - val_accuracy: 0.8319
# Epoch 29/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3294 - accuracy: 0.8659 - val_loss: 0.4361 - val_accuracy: 0.8101
# Epoch 30/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3811 - accuracy: 0.8345 - val_loss: 0.4282 - val_accuracy: 0.8258
# Epoch 31/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3437 - accuracy: 0.8510 - val_loss: 0.4312 - val_accuracy: 0.8300
# Epoch 32/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3127 - accuracy: 0.8704 - val_loss: 0.4276 - val_accuracy: 0.8258
# Epoch 33/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3414 - accuracy: 0.8523 - val_loss: 0.4314 - val_accuracy: 0.8362
# Epoch 34/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3273 - accuracy: 0.8554 - val_loss: 0.4336 - val_accuracy: 0.8325
# Epoch 35/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.4077 - accuracy: 0.8234 - val_loss: 0.4389 - val_accuracy: 0.8278
# Epoch 36/50
# 134/134 [==============================] - 32s 238ms/step - loss: 0.3431 - accuracy: 0.8532 - val_loss: 0.4335 - val_accuracy: 0.8272
# Epoch 37/50
# 134/134 [==============================] - 31s 235ms/step - loss: 0.3153 - accuracy: 0.8709 - val_loss: 0.4386 - val_accuracy: 0.8158
# Epoch 38/50
# 134/134 [==============================] - 31s 234ms/step - loss: 0.3365 - accuracy: 0.8556 - val_loss: 0.4368 - val_accuracy: 0.8210
# Epoch 39/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3384 - accuracy: 0.8524 - val_loss: 0.4247 - val_accuracy: 0.8239
# Epoch 40/50
# 134/134 [==============================] - 31s 236ms/step - loss: 0.3458 - accuracy: 0.8425 - val_loss: 0.4296 - val_accuracy: 0.8286
# Epoch 41/50
# 134/134 [==============================] - 32s 239ms/step - loss: 0.2952 - accuracy: 0.8751 - val_loss: 0.4540 - val_accuracy: 0.8045
# Epoch 42/50
# 134/134 [==============================] - 32s 239ms/step - loss: 0.3289 - accuracy: 0.8544 - val_loss: 0.4248 - val_accuracy: 0.8210
# Epoch 43/50
# 134/134 [==============================] - 32s 236ms/step - loss: 0.3379 - accuracy: 0.8511 - val_loss: 0.4367 - val_accuracy: 0.8295
# Epoch 44/50
# 134/134 [==============================] - 32s 240ms/step - loss: 0.3099 - accuracy: 0.8629 - val_loss: 0.4351 - val_accuracy: 0.8220
# Epoch 45/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3556 - accuracy: 0.8463 - val_loss: 0.4253 - val_accuracy: 0.8205
# Epoch 46/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3338 - accuracy: 0.8549 - val_loss: 0.4248 - val_accuracy: 0.8182
# Epoch 47/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3317 - accuracy: 0.8519 - val_loss: 0.4311 - val_accuracy: 0.8177
# Epoch 48/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3314 - accuracy: 0.8511 - val_loss: 0.4413 - val_accuracy: 0.8262
# Epoch 49/50
# 134/134 [==============================] - 32s 237ms/step - loss: 0.3250 - accuracy: 0.8633 - val_loss: 0.4409 - val_accuracy: 0.8149
# Epoch 50/50
# 134/134 [==============================] - 32s 236ms/step - loss: 0.3302 - accuracy: 0.8525 - val_loss: 0.4427 - val_accuracy: 0.8262
# Vgg16 test accuracy: 0.8125

# %% [markdown]
# #Comparisons

# %%
def load_models(preds, model_name):
  from keras.models import load_model

  current_model = load_model(os.path.join(MODELS_DIR,'baseline_'+model_name+'.h5'))
  if model_name == "scratch":
    model_preds = current_model.predict([test_data_baseline, test_data_no_baseline])
  else:
    model_preds = current_model.predict([test_data_baseline_RGB, test_data_no_baseline_RGB])

  for pred in model_preds:
    preds.append(pred[0])


#execute fine tuning in a secondary process to avoid RAM saturation
models = ["scratch", "resnet", "vgg16"]
for model in models:
  preds = process_manager.list()
  p = multiprocessing.Process(target=load_models, args=(preds, model))
  p.start()
  p.join()

  preds = np.asarray(preds)

  show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
  print("\n" + model + " test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

  final_models_preds.update({model: preds})
# Out:
# scratch test accuracy: 0.6696428571428571
# resnet test accuracy: 0.8422619047619048
# vgg16 test accuracy: 0.8125

# %%
show_roc_curves(final_models_preds)

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# ##Resnet

# %%
def resnet_fine_tuning(resnet_preds):
  if VERBOSE == 1: print("Testing")
  import keras
  from keras.models import load_model
  from keras.applications.resnet import preprocess_input as resnet_preprocess
  
  resnet_train_generator = get_train_generator(train_data_b_RGB, train_labels_b_RGB, train_data_nb_RGB, train_labels_nb_RGB, resnet_preprocess)
  resnet_validation_generator = get_validation_generator(val_data_b_RGB, val_labels_b_RGB, val_data_nb_RGB, val_labels_nb_RGB, resnet_preprocess)

  final_model = load_model(os.path.join(MODELS_DIR,'baseline_resnet.h5'))

  convolutional_layer = final_model.get_layer("resnet50") 
  
  for layer in convolutional_layer.layers:
    layer.trainable = False

  for layer in convolutional_layer.layers:
      if layer.name == "conv5_block3_3_conv":
        layer.trainable = True
  
  ada = keras.optimizers.Adam(learning_rate=0.0001)
  final_model.compile(loss="binary_crossentropy", optimizer=ada, metrics=['accuracy'])

  fit_results = final_model.fit(
      resnet_train_generator,
      epochs=RESNET_TRAIN_EPOCHS,
      steps_per_epoch=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      validation_data=resnet_validation_generator,
      validation_steps=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      verbose=VERBOSE
  )

  show_accuracy_loss_trends(fit_results.history)

  preds = final_model.predict([test_data_baseline_RGB, test_data_no_baseline_RGB])
  for pred in preds:
    resnet_preds.append(pred[0])
  
  final_model.save(os.path.join(MODELS_DIR,'baseline_resnet_tuned.h5'))

# %%
preds = process_manager.list()

#execute fine tuning in a secondary process to avoid RAM saturation
p = multiprocessing.Process(target=resnet_fine_tuning, args=(preds, ))
p.start()
p.join()

preds = np.asarray(preds)

show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
print("\nTuned resnet test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

fine_tuned_models_preds.update({"resnet_tuned": preds})
# Out:
# Testing
# Epoch 1/200
# 134/134 [==============================] - 43s 235ms/step - loss: 0.3411 - accuracy: 0.8564 - val_loss: 0.3810 - val_accuracy: 0.8396
# Epoch 2/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3612 - accuracy: 0.8413 - val_loss: 0.3825 - val_accuracy: 0.8400
# Epoch 3/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3689 - accuracy: 0.8474 - val_loss: 0.3847 - val_accuracy: 0.8343
# Epoch 4/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3546 - accuracy: 0.8574 - val_loss: 0.3893 - val_accuracy: 0.8371
# Epoch 5/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3475 - accuracy: 0.8520 - val_loss: 0.4054 - val_accuracy: 0.8362
# Epoch 6/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3468 - accuracy: 0.8515 - val_loss: 0.4166 - val_accuracy: 0.8376
# Epoch 7/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3676 - accuracy: 0.8326 - val_loss: 0.3938 - val_accuracy: 0.8310
# Epoch 8/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3303 - accuracy: 0.8636 - val_loss: 0.3884 - val_accuracy: 0.8371
# Epoch 9/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3573 - accuracy: 0.8576 - val_loss: 0.3990 - val_accuracy: 0.8376
# Epoch 10/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3372 - accuracy: 0.8673 - val_loss: 0.3794 - val_accuracy: 0.8423
# Epoch 11/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3322 - accuracy: 0.8461 - val_loss: 0.3924 - val_accuracy: 0.8362
# Epoch 12/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3607 - accuracy: 0.8463 - val_loss: 0.3770 - val_accuracy: 0.8400
# Epoch 13/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3494 - accuracy: 0.8463 - val_loss: 0.3651 - val_accuracy: 0.8371
# Epoch 14/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3347 - accuracy: 0.8647 - val_loss: 0.3840 - val_accuracy: 0.8305
# Epoch 15/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3411 - accuracy: 0.8605 - val_loss: 0.3695 - val_accuracy: 0.8286
# Epoch 16/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3681 - accuracy: 0.8517 - val_loss: 0.3790 - val_accuracy: 0.8409
# Epoch 17/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3516 - accuracy: 0.8502 - val_loss: 0.3737 - val_accuracy: 0.8423
# Epoch 18/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3594 - accuracy: 0.8386 - val_loss: 0.3846 - val_accuracy: 0.8366
# Epoch 19/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3472 - accuracy: 0.8679 - val_loss: 0.3971 - val_accuracy: 0.8371
# Epoch 20/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3234 - accuracy: 0.8588 - val_loss: 0.3605 - val_accuracy: 0.8442
# Epoch 21/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3640 - accuracy: 0.8398 - val_loss: 0.3748 - val_accuracy: 0.8438
# Epoch 22/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4297 - accuracy: 0.8134 - val_loss: 0.3719 - val_accuracy: 0.8390
# Epoch 23/200
# 134/134 [==============================] - 30s 221ms/step - loss: 0.3454 - accuracy: 0.8482 - val_loss: 0.3847 - val_accuracy: 0.8357
# Epoch 24/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3495 - accuracy: 0.8462 - val_loss: 0.3816 - val_accuracy: 0.8348
# Epoch 25/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3614 - accuracy: 0.8482 - val_loss: 0.4120 - val_accuracy: 0.8366
# Epoch 26/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3569 - accuracy: 0.8467 - val_loss: 0.3727 - val_accuracy: 0.8338
# Epoch 27/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3618 - accuracy: 0.8539 - val_loss: 0.3646 - val_accuracy: 0.8461
# Epoch 28/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3509 - accuracy: 0.8467 - val_loss: 0.3873 - val_accuracy: 0.8404
# Epoch 29/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3285 - accuracy: 0.8660 - val_loss: 0.3790 - val_accuracy: 0.8357
# Epoch 30/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3416 - accuracy: 0.8523 - val_loss: 0.3788 - val_accuracy: 0.8329
# Epoch 31/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3590 - accuracy: 0.8455 - val_loss: 0.3663 - val_accuracy: 0.8456
# Epoch 32/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3439 - accuracy: 0.8548 - val_loss: 0.3794 - val_accuracy: 0.8409
# Epoch 33/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3352 - accuracy: 0.8743 - val_loss: 0.3778 - val_accuracy: 0.8324
# Epoch 34/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3312 - accuracy: 0.8634 - val_loss: 0.3888 - val_accuracy: 0.8354
# Epoch 35/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3593 - accuracy: 0.8408 - val_loss: 0.3893 - val_accuracy: 0.8325
# Epoch 36/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3295 - accuracy: 0.8551 - val_loss: 0.3774 - val_accuracy: 0.8433
# Epoch 37/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3498 - accuracy: 0.8638 - val_loss: 0.4125 - val_accuracy: 0.8366
# Epoch 38/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3570 - accuracy: 0.8544 - val_loss: 0.3753 - val_accuracy: 0.8409
# Epoch 39/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3595 - accuracy: 0.8561 - val_loss: 0.3693 - val_accuracy: 0.8371
# Epoch 40/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3484 - accuracy: 0.8463 - val_loss: 0.4147 - val_accuracy: 0.8277
# Epoch 41/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3207 - accuracy: 0.8711 - val_loss: 0.3685 - val_accuracy: 0.8480
# Epoch 42/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3439 - accuracy: 0.8615 - val_loss: 0.3648 - val_accuracy: 0.8466
# Epoch 43/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3381 - accuracy: 0.8590 - val_loss: 0.3780 - val_accuracy: 0.8414
# Epoch 44/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3186 - accuracy: 0.8580 - val_loss: 0.3724 - val_accuracy: 0.8513
# Epoch 45/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.4542 - accuracy: 0.7879 - val_loss: 0.3605 - val_accuracy: 0.8456
# Epoch 46/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3563 - accuracy: 0.8546 - val_loss: 0.3587 - val_accuracy: 0.8471
# Epoch 47/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3438 - accuracy: 0.8520 - val_loss: 0.3691 - val_accuracy: 0.8452
# Epoch 48/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3259 - accuracy: 0.8685 - val_loss: 0.3796 - val_accuracy: 0.8357
# Epoch 49/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3679 - accuracy: 0.8438 - val_loss: 0.3689 - val_accuracy: 0.8404
# Epoch 50/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3441 - accuracy: 0.8581 - val_loss: 0.3717 - val_accuracy: 0.8423
# Epoch 51/200
# 134/134 [==============================] - 31s 229ms/step - loss: 0.3297 - accuracy: 0.8631 - val_loss: 0.3969 - val_accuracy: 0.8338
# Epoch 52/200
# 134/134 [==============================] - 30s 228ms/step - loss: 0.3553 - accuracy: 0.8447 - val_loss: 0.3588 - val_accuracy: 0.8461
# Epoch 53/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3442 - accuracy: 0.8468 - val_loss: 0.3943 - val_accuracy: 0.8414
# Epoch 54/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3614 - accuracy: 0.8506 - val_loss: 0.3781 - val_accuracy: 0.8447
# Epoch 55/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3522 - accuracy: 0.8513 - val_loss: 0.3770 - val_accuracy: 0.8523
# Epoch 56/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3587 - accuracy: 0.8597 - val_loss: 0.3735 - val_accuracy: 0.8414
# Epoch 57/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3240 - accuracy: 0.8649 - val_loss: 0.3747 - val_accuracy: 0.8485
# Epoch 58/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3297 - accuracy: 0.8685 - val_loss: 0.3855 - val_accuracy: 0.8452
# Epoch 59/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3680 - accuracy: 0.8536 - val_loss: 0.3662 - val_accuracy: 0.8447
# Epoch 60/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3571 - accuracy: 0.8535 - val_loss: 0.3775 - val_accuracy: 0.8329
# Epoch 61/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3906 - accuracy: 0.8180 - val_loss: 0.3897 - val_accuracy: 0.8366
# Epoch 62/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3726 - accuracy: 0.8363 - val_loss: 0.3605 - val_accuracy: 0.8466
# Epoch 63/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3308 - accuracy: 0.8558 - val_loss: 0.3763 - val_accuracy: 0.8442
# Epoch 64/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3187 - accuracy: 0.8745 - val_loss: 0.3998 - val_accuracy: 0.8385
# Epoch 65/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3451 - accuracy: 0.8614 - val_loss: 0.3838 - val_accuracy: 0.8376
# Epoch 66/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3499 - accuracy: 0.8462 - val_loss: 0.4121 - val_accuracy: 0.8348
# Epoch 67/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3185 - accuracy: 0.8757 - val_loss: 0.3700 - val_accuracy: 0.8456
# Epoch 68/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3117 - accuracy: 0.8696 - val_loss: 0.3763 - val_accuracy: 0.8382
# Epoch 69/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3311 - accuracy: 0.8591 - val_loss: 0.3780 - val_accuracy: 0.8354
# Epoch 70/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3165 - accuracy: 0.8696 - val_loss: 0.3781 - val_accuracy: 0.8499
# Epoch 71/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3552 - accuracy: 0.8525 - val_loss: 0.4031 - val_accuracy: 0.8324
# Epoch 72/200
# 134/134 [==============================] - 29s 221ms/step - loss: 0.3349 - accuracy: 0.8643 - val_loss: 0.3797 - val_accuracy: 0.8471
# Epoch 73/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3310 - accuracy: 0.8773 - val_loss: 0.3826 - val_accuracy: 0.8542
# Epoch 74/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3474 - accuracy: 0.8559 - val_loss: 0.3669 - val_accuracy: 0.8542
# Epoch 75/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3568 - accuracy: 0.8460 - val_loss: 0.3794 - val_accuracy: 0.8381
# Epoch 76/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3425 - accuracy: 0.8583 - val_loss: 0.3885 - val_accuracy: 0.8395
# Epoch 77/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3541 - accuracy: 0.8528 - val_loss: 0.3962 - val_accuracy: 0.8428
# Epoch 78/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3245 - accuracy: 0.8664 - val_loss: 0.4193 - val_accuracy: 0.8400
# Epoch 79/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3432 - accuracy: 0.8490 - val_loss: 0.3793 - val_accuracy: 0.8480
# Epoch 80/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3311 - accuracy: 0.8641 - val_loss: 0.3749 - val_accuracy: 0.8456
# Epoch 81/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3424 - accuracy: 0.8447 - val_loss: 0.4011 - val_accuracy: 0.8324
# Epoch 82/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3208 - accuracy: 0.8690 - val_loss: 0.3887 - val_accuracy: 0.8357
# Epoch 83/200
# 134/134 [==============================] - 30s 222ms/step - loss: 0.3606 - accuracy: 0.8575 - val_loss: 0.3669 - val_accuracy: 0.8442
# Epoch 84/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3370 - accuracy: 0.8566 - val_loss: 0.3948 - val_accuracy: 0.8390
# Epoch 85/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3473 - accuracy: 0.8544 - val_loss: 0.3834 - val_accuracy: 0.8395
# Epoch 86/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3418 - accuracy: 0.8619 - val_loss: 0.3920 - val_accuracy: 0.8366
# Epoch 87/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3426 - accuracy: 0.8586 - val_loss: 0.3727 - val_accuracy: 0.8395
# Epoch 88/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3280 - accuracy: 0.8652 - val_loss: 0.4191 - val_accuracy: 0.8319
# Epoch 89/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3277 - accuracy: 0.8589 - val_loss: 0.4098 - val_accuracy: 0.8305
# Epoch 90/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3360 - accuracy: 0.8565 - val_loss: 0.3836 - val_accuracy: 0.8376
# Epoch 91/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3438 - accuracy: 0.8471 - val_loss: 0.3998 - val_accuracy: 0.8423
# Epoch 92/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3098 - accuracy: 0.8738 - val_loss: 0.3968 - val_accuracy: 0.8390
# Epoch 93/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3472 - accuracy: 0.8409 - val_loss: 0.3945 - val_accuracy: 0.8438
# Epoch 94/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3264 - accuracy: 0.8635 - val_loss: 0.3854 - val_accuracy: 0.8485
# Epoch 95/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3205 - accuracy: 0.8722 - val_loss: 0.3881 - val_accuracy: 0.8357
# Epoch 96/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3297 - accuracy: 0.8721 - val_loss: 0.3760 - val_accuracy: 0.8490
# Epoch 97/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3483 - accuracy: 0.8600 - val_loss: 0.4134 - val_accuracy: 0.8452
# Epoch 98/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3200 - accuracy: 0.8748 - val_loss: 0.3750 - val_accuracy: 0.8499
# Epoch 99/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3549 - accuracy: 0.8463 - val_loss: 0.4006 - val_accuracy: 0.8376
# Epoch 100/200
# 134/134 [==============================] - 31s 229ms/step - loss: 0.3423 - accuracy: 0.8652 - val_loss: 0.3783 - val_accuracy: 0.8485
# Epoch 101/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3296 - accuracy: 0.8616 - val_loss: 0.3835 - val_accuracy: 0.8480
# Epoch 102/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3428 - accuracy: 0.8594 - val_loss: 0.3902 - val_accuracy: 0.8401
# Epoch 103/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3649 - accuracy: 0.8413 - val_loss: 0.3812 - val_accuracy: 0.8500
# Epoch 104/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3187 - accuracy: 0.8713 - val_loss: 0.3882 - val_accuracy: 0.8461
# Epoch 105/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3269 - accuracy: 0.8529 - val_loss: 0.3999 - val_accuracy: 0.8433
# Epoch 106/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3227 - accuracy: 0.8660 - val_loss: 0.3729 - val_accuracy: 0.8537
# Epoch 107/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3529 - accuracy: 0.8523 - val_loss: 0.4292 - val_accuracy: 0.8381
# Epoch 108/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3459 - accuracy: 0.8591 - val_loss: 0.3751 - val_accuracy: 0.8523
# Epoch 109/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3594 - accuracy: 0.8505 - val_loss: 0.3956 - val_accuracy: 0.8433
# Epoch 110/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3496 - accuracy: 0.8385 - val_loss: 0.3702 - val_accuracy: 0.8537
# Epoch 111/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3368 - accuracy: 0.8606 - val_loss: 0.3955 - val_accuracy: 0.8428
# Epoch 112/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3413 - accuracy: 0.8645 - val_loss: 0.3926 - val_accuracy: 0.8385
# Epoch 113/200
# 134/134 [==============================] - 30s 228ms/step - loss: 0.3329 - accuracy: 0.8587 - val_loss: 0.4052 - val_accuracy: 0.8324
# Epoch 114/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3276 - accuracy: 0.8674 - val_loss: 0.3720 - val_accuracy: 0.8471
# Epoch 115/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3257 - accuracy: 0.8738 - val_loss: 0.4151 - val_accuracy: 0.8314
# Epoch 116/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3339 - accuracy: 0.8574 - val_loss: 0.3846 - val_accuracy: 0.8423
# Epoch 117/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3155 - accuracy: 0.8599 - val_loss: 0.4017 - val_accuracy: 0.8366
# Epoch 118/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3317 - accuracy: 0.8563 - val_loss: 0.3826 - val_accuracy: 0.8485
# Epoch 119/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3281 - accuracy: 0.8659 - val_loss: 0.3766 - val_accuracy: 0.8466
# Epoch 120/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3311 - accuracy: 0.8689 - val_loss: 0.3747 - val_accuracy: 0.8532
# Epoch 121/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3310 - accuracy: 0.8674 - val_loss: 0.4287 - val_accuracy: 0.8324
# Epoch 122/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.4552 - accuracy: 0.8035 - val_loss: 0.4182 - val_accuracy: 0.8376
# Epoch 123/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3750 - accuracy: 0.8504 - val_loss: 0.3560 - val_accuracy: 0.8537
# Epoch 124/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3381 - accuracy: 0.8724 - val_loss: 0.4160 - val_accuracy: 0.8333
# Epoch 125/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3364 - accuracy: 0.8579 - val_loss: 0.3819 - val_accuracy: 0.8480
# Epoch 126/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3489 - accuracy: 0.8582 - val_loss: 0.3802 - val_accuracy: 0.8589
# Epoch 127/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3368 - accuracy: 0.8582 - val_loss: 0.3840 - val_accuracy: 0.8485
# Epoch 128/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.4653 - accuracy: 0.7836 - val_loss: 0.4445 - val_accuracy: 0.8139
# Epoch 129/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3536 - accuracy: 0.8464 - val_loss: 0.3948 - val_accuracy: 0.8357
# Epoch 130/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3598 - accuracy: 0.8456 - val_loss: 0.4102 - val_accuracy: 0.8310
# Epoch 131/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3498 - accuracy: 0.8521 - val_loss: 0.3953 - val_accuracy: 0.8400
# Epoch 132/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3256 - accuracy: 0.8606 - val_loss: 0.3708 - val_accuracy: 0.8447
# Epoch 133/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3153 - accuracy: 0.8758 - val_loss: 0.3633 - val_accuracy: 0.8532
# Epoch 134/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3324 - accuracy: 0.8680 - val_loss: 0.3701 - val_accuracy: 0.8490
# Epoch 135/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3630 - accuracy: 0.8505 - val_loss: 0.3731 - val_accuracy: 0.8433
# Epoch 136/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3534 - accuracy: 0.8477 - val_loss: 0.3799 - val_accuracy: 0.8448
# Epoch 137/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3304 - accuracy: 0.8649 - val_loss: 0.3689 - val_accuracy: 0.8467
# Epoch 138/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3272 - accuracy: 0.8577 - val_loss: 0.3728 - val_accuracy: 0.8589
# Epoch 139/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3465 - accuracy: 0.8503 - val_loss: 0.3814 - val_accuracy: 0.8499
# Epoch 140/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3350 - accuracy: 0.8681 - val_loss: 0.3818 - val_accuracy: 0.8485
# Epoch 141/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3098 - accuracy: 0.8745 - val_loss: 0.4070 - val_accuracy: 0.8357
# Epoch 142/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3242 - accuracy: 0.8530 - val_loss: 0.3793 - val_accuracy: 0.8556
# Epoch 143/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3363 - accuracy: 0.8622 - val_loss: 0.3812 - val_accuracy: 0.8438
# Epoch 144/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3221 - accuracy: 0.8660 - val_loss: 0.3787 - val_accuracy: 0.8490
# Epoch 145/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3405 - accuracy: 0.8625 - val_loss: 0.3835 - val_accuracy: 0.8376
# Epoch 146/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3379 - accuracy: 0.8626 - val_loss: 0.3714 - val_accuracy: 0.8456
# Epoch 147/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3322 - accuracy: 0.8600 - val_loss: 0.3841 - val_accuracy: 0.8490
# Epoch 148/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3214 - accuracy: 0.8674 - val_loss: 0.3686 - val_accuracy: 0.8537
# Epoch 149/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3470 - accuracy: 0.8463 - val_loss: 0.3744 - val_accuracy: 0.8513
# Epoch 150/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3408 - accuracy: 0.8617 - val_loss: 0.3908 - val_accuracy: 0.8404
# Epoch 151/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3363 - accuracy: 0.8751 - val_loss: 0.3847 - val_accuracy: 0.8499
# Epoch 152/200
# 134/134 [==============================] - 30s 229ms/step - loss: 0.4105 - accuracy: 0.8170 - val_loss: 0.4004 - val_accuracy: 0.8357
# Epoch 153/200
# 134/134 [==============================] - 30s 227ms/step - loss: 0.3493 - accuracy: 0.8564 - val_loss: 0.3757 - val_accuracy: 0.8471
# Epoch 154/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3300 - accuracy: 0.8619 - val_loss: 0.4087 - val_accuracy: 0.8319
# Epoch 155/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3030 - accuracy: 0.8648 - val_loss: 0.3613 - val_accuracy: 0.8594
# Epoch 156/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3382 - accuracy: 0.8440 - val_loss: 0.3792 - val_accuracy: 0.8532
# Epoch 157/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3244 - accuracy: 0.8573 - val_loss: 0.3729 - val_accuracy: 0.8475
# Epoch 158/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3046 - accuracy: 0.8685 - val_loss: 0.3829 - val_accuracy: 0.8419
# Epoch 159/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3201 - accuracy: 0.8626 - val_loss: 0.3833 - val_accuracy: 0.8409
# Epoch 160/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3244 - accuracy: 0.8609 - val_loss: 0.3771 - val_accuracy: 0.8452
# Epoch 161/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3335 - accuracy: 0.8649 - val_loss: 0.3776 - val_accuracy: 0.8504
# Epoch 162/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3064 - accuracy: 0.8850 - val_loss: 0.4035 - val_accuracy: 0.8329
# Epoch 163/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3390 - accuracy: 0.8654 - val_loss: 0.3825 - val_accuracy: 0.8428
# Epoch 164/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3232 - accuracy: 0.8711 - val_loss: 0.4262 - val_accuracy: 0.8324
# Epoch 165/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3160 - accuracy: 0.8716 - val_loss: 0.4614 - val_accuracy: 0.8187
# Epoch 166/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3117 - accuracy: 0.8756 - val_loss: 0.3801 - val_accuracy: 0.8423
# Epoch 167/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3187 - accuracy: 0.8648 - val_loss: 0.3720 - val_accuracy: 0.8447
# Epoch 168/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3319 - accuracy: 0.8613 - val_loss: 0.4174 - val_accuracy: 0.8333
# Epoch 169/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3279 - accuracy: 0.8573 - val_loss: 0.4000 - val_accuracy: 0.8348
# Epoch 170/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3348 - accuracy: 0.8560 - val_loss: 0.3770 - val_accuracy: 0.8420
# Epoch 171/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3305 - accuracy: 0.8596 - val_loss: 0.3941 - val_accuracy: 0.8349
# Epoch 172/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3369 - accuracy: 0.8474 - val_loss: 0.3945 - val_accuracy: 0.8324
# Epoch 173/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3109 - accuracy: 0.8664 - val_loss: 0.4060 - val_accuracy: 0.8362
# Epoch 174/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3361 - accuracy: 0.8612 - val_loss: 0.3924 - val_accuracy: 0.8438
# Epoch 175/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3715 - accuracy: 0.8276 - val_loss: 0.3828 - val_accuracy: 0.8485
# Epoch 176/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3192 - accuracy: 0.8744 - val_loss: 0.3802 - val_accuracy: 0.8527
# Epoch 177/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3421 - accuracy: 0.8544 - val_loss: 0.3900 - val_accuracy: 0.8362
# Epoch 178/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3297 - accuracy: 0.8594 - val_loss: 0.3749 - val_accuracy: 0.8471
# Epoch 179/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3343 - accuracy: 0.8641 - val_loss: 0.3731 - val_accuracy: 0.8423
# Epoch 180/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3228 - accuracy: 0.8599 - val_loss: 0.3706 - val_accuracy: 0.8494
# Epoch 181/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3288 - accuracy: 0.8665 - val_loss: 0.4051 - val_accuracy: 0.8438
# Epoch 182/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3212 - accuracy: 0.8687 - val_loss: 0.3819 - val_accuracy: 0.8414
# Epoch 183/200
# 134/134 [==============================] - 30s 226ms/step - loss: 0.3333 - accuracy: 0.8559 - val_loss: 0.3802 - val_accuracy: 0.8580
# Epoch 184/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3124 - accuracy: 0.8708 - val_loss: 0.3693 - val_accuracy: 0.8546
# Epoch 185/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3377 - accuracy: 0.8673 - val_loss: 0.3761 - val_accuracy: 0.8475
# Epoch 186/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3488 - accuracy: 0.8577 - val_loss: 0.3870 - val_accuracy: 0.8452
# Epoch 187/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3101 - accuracy: 0.8713 - val_loss: 0.3961 - val_accuracy: 0.8485
# Epoch 188/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3330 - accuracy: 0.8623 - val_loss: 0.3659 - val_accuracy: 0.8527
# Epoch 189/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3335 - accuracy: 0.8513 - val_loss: 0.3902 - val_accuracy: 0.8485
# Epoch 190/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3387 - accuracy: 0.8663 - val_loss: 0.3876 - val_accuracy: 0.8542
# Epoch 191/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3114 - accuracy: 0.8670 - val_loss: 0.3785 - val_accuracy: 0.8433
# Epoch 192/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3462 - accuracy: 0.8497 - val_loss: 0.3954 - val_accuracy: 0.8494
# Epoch 193/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3313 - accuracy: 0.8586 - val_loss: 0.3877 - val_accuracy: 0.8504
# Epoch 194/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3292 - accuracy: 0.8621 - val_loss: 0.4046 - val_accuracy: 0.8452
# Epoch 195/200
# 134/134 [==============================] - 30s 223ms/step - loss: 0.3454 - accuracy: 0.8606 - val_loss: 0.3929 - val_accuracy: 0.8381
# Epoch 196/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3321 - accuracy: 0.8646 - val_loss: 0.4122 - val_accuracy: 0.8362
# Epoch 197/200
# 134/134 [==============================] - 30s 225ms/step - loss: 0.3208 - accuracy: 0.8574 - val_loss: 0.3829 - val_accuracy: 0.8381
# Epoch 198/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3320 - accuracy: 0.8535 - val_loss: 0.3963 - val_accuracy: 0.8466
# Epoch 199/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3201 - accuracy: 0.8681 - val_loss: 0.3697 - val_accuracy: 0.8452
# Epoch 200/200
# 134/134 [==============================] - 30s 224ms/step - loss: 0.3350 - accuracy: 0.8642 - val_loss: 0.3810 - val_accuracy: 0.8494
# Tuned resnet test accuracy: 0.8333333333333334

# %% [markdown]
# ##VGG16

# %%
def vgg16_fine_tuning(vgg16_preds):
  if VERBOSE == 1: print("Testing")
  import keras
  from keras.models import load_model
  from keras.applications.vgg16 import preprocess_input as vgg16_preprocess

  vgg16_train_generator = get_train_generator(train_data_b_RGB, train_labels_b_RGB, train_data_nb_RGB, train_labels_nb_RGB, vgg16_preprocess)
  vgg16_validation_generator = get_validation_generator(val_data_b_RGB, val_labels_b_RGB, val_data_nb_RGB, val_labels_nb_RGB, vgg16_preprocess)

  final_model = load_model(os.path.join(MODELS_DIR,'baseline_vgg16.h5'))

  convolutional_layer = final_model.get_layer("vgg16") 

  for layer in convolutional_layer.layers:
    layer.trainable = False

  for layer in convolutional_layer.layers[-4:]:
    layer.trainable = True
 
  rms = keras.optimizers.RMSprop(lr=2e-6)
  final_model.compile(loss="binary_crossentropy", optimizer=rms, metrics=['accuracy'])

  fit_results = final_model.fit(
      vgg16_train_generator,
      epochs=VGG16_TRAIN_EPOCHS,
      steps_per_epoch=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      validation_data=vgg16_validation_generator,
      validation_steps=int(np.ceil(len(train_data_b_RGB) / float(BATCH_SIZE))),
      verbose=VERBOSE
  )


  show_accuracy_loss_trends(fit_results.history)

  preds = final_model.predict([test_data_baseline_RGB, test_data_no_baseline_RGB])
  for pred in preds:
    vgg16_preds.append(pred[0])
  
  final_model.save(os.path.join(MODELS_DIR,'baseline_vgg16_tuned.h5'))

# %%
preds = process_manager.list()

#execute fine tuning in a secondary process to avoid RAM saturation
p = multiprocessing.Process(target=vgg16_fine_tuning, args=(preds, ))
p.start()
p.join()

preds = np.asarray(preds)

show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
print("\nTuned VGG16 test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

fine_tuned_models_preds.update({"vgg16_tuned": preds})
# Out:
# Testing
# Epoch 1/50
# 134/134 [==============================] - 43s 251ms/step - loss: 0.2949 - accuracy: 0.8746 - val_loss: 0.4420 - val_accuracy: 0.8236
# Epoch 2/50
# 134/134 [==============================] - 32s 240ms/step - loss: 0.3205 - accuracy: 0.8622 - val_loss: 0.4322 - val_accuracy: 0.8291
# Epoch 3/50
# 134/134 [==============================] - 33s 245ms/step - loss: 0.2962 - accuracy: 0.8703 - val_loss: 0.4281 - val_accuracy: 0.8390
# Epoch 4/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2832 - accuracy: 0.8952 - val_loss: 0.4286 - val_accuracy: 0.8366
# Epoch 5/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2785 - accuracy: 0.8862 - val_loss: 0.4253 - val_accuracy: 0.8433
# Epoch 6/50
# 134/134 [==============================] - 33s 247ms/step - loss: 0.2587 - accuracy: 0.8936 - val_loss: 0.4117 - val_accuracy: 0.8428
# Epoch 7/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2951 - accuracy: 0.8656 - val_loss: 0.4204 - val_accuracy: 0.8419
# Epoch 8/50
# 134/134 [==============================] - 33s 247ms/step - loss: 0.2469 - accuracy: 0.8953 - val_loss: 0.4011 - val_accuracy: 0.8447
# Epoch 9/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.3631 - accuracy: 0.8598 - val_loss: 0.3972 - val_accuracy: 0.8400
# Epoch 10/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.2534 - accuracy: 0.9064 - val_loss: 0.4008 - val_accuracy: 0.8499
# Epoch 11/50
# 134/134 [==============================] - 33s 251ms/step - loss: 0.2472 - accuracy: 0.9082 - val_loss: 0.3957 - val_accuracy: 0.8485
# Epoch 12/50
# 134/134 [==============================] - 33s 250ms/step - loss: 0.2565 - accuracy: 0.8957 - val_loss: 0.3935 - val_accuracy: 0.8423
# Epoch 13/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2819 - accuracy: 0.8861 - val_loss: 0.3951 - val_accuracy: 0.8423
# Epoch 14/50
# 134/134 [==============================] - 33s 250ms/step - loss: 0.2420 - accuracy: 0.9018 - val_loss: 0.3850 - val_accuracy: 0.8518
# Epoch 15/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.2546 - accuracy: 0.9062 - val_loss: 0.3779 - val_accuracy: 0.8475
# Epoch 16/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2659 - accuracy: 0.8906 - val_loss: 0.3843 - val_accuracy: 0.8494
# Epoch 17/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.2400 - accuracy: 0.8994 - val_loss: 0.3928 - val_accuracy: 0.8542
# Epoch 18/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.2487 - accuracy: 0.9005 - val_loss: 0.3777 - val_accuracy: 0.8594
# Epoch 19/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2156 - accuracy: 0.9014 - val_loss: 0.3909 - val_accuracy: 0.8504
# Epoch 20/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2177 - accuracy: 0.9169 - val_loss: 0.3783 - val_accuracy: 0.8537
# Epoch 21/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.2306 - accuracy: 0.9053 - val_loss: 0.3938 - val_accuracy: 0.8485
# Epoch 22/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.3360 - accuracy: 0.8679 - val_loss: 0.3633 - val_accuracy: 0.8594
# Epoch 23/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2183 - accuracy: 0.9094 - val_loss: 0.3835 - val_accuracy: 0.8589
# Epoch 24/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2205 - accuracy: 0.9149 - val_loss: 0.3701 - val_accuracy: 0.8575
# Epoch 25/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2287 - accuracy: 0.9095 - val_loss: 0.3759 - val_accuracy: 0.8608
# Epoch 26/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2133 - accuracy: 0.9258 - val_loss: 0.3681 - val_accuracy: 0.8561
# Epoch 27/50
# 134/134 [==============================] - 33s 247ms/step - loss: 0.2147 - accuracy: 0.9073 - val_loss: 0.3716 - val_accuracy: 0.8632
# Epoch 28/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2462 - accuracy: 0.9015 - val_loss: 0.3705 - val_accuracy: 0.8608
# Epoch 29/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1882 - accuracy: 0.9325 - val_loss: 0.3856 - val_accuracy: 0.8589
# Epoch 30/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2344 - accuracy: 0.9034 - val_loss: 0.3730 - val_accuracy: 0.8617
# Epoch 31/50
# 134/134 [==============================] - 33s 250ms/step - loss: 0.2239 - accuracy: 0.9008 - val_loss: 0.3845 - val_accuracy: 0.8584
# Epoch 32/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1922 - accuracy: 0.9198 - val_loss: 0.3550 - val_accuracy: 0.8674
# Epoch 33/50
# 134/134 [==============================] - 33s 247ms/step - loss: 0.2046 - accuracy: 0.9235 - val_loss: 0.3660 - val_accuracy: 0.8655
# Epoch 34/50
# 134/134 [==============================] - 33s 249ms/step - loss: 0.2038 - accuracy: 0.9181 - val_loss: 0.3620 - val_accuracy: 0.8665
# Epoch 35/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2234 - accuracy: 0.9046 - val_loss: 0.3689 - val_accuracy: 0.8670
# Epoch 36/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1907 - accuracy: 0.9246 - val_loss: 0.3666 - val_accuracy: 0.8655
# Epoch 37/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1694 - accuracy: 0.9352 - val_loss: 0.3642 - val_accuracy: 0.8584
# Epoch 38/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1955 - accuracy: 0.9163 - val_loss: 0.3644 - val_accuracy: 0.8565
# Epoch 39/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1976 - accuracy: 0.9203 - val_loss: 0.3620 - val_accuracy: 0.8641
# Epoch 40/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1932 - accuracy: 0.9172 - val_loss: 0.3670 - val_accuracy: 0.8665
# Epoch 41/50
# 134/134 [==============================] - 33s 250ms/step - loss: 0.1698 - accuracy: 0.9376 - val_loss: 0.3650 - val_accuracy: 0.8627
# Epoch 42/50
# 134/134 [==============================] - 33s 247ms/step - loss: 0.1835 - accuracy: 0.9251 - val_loss: 0.3537 - val_accuracy: 0.8660
# Epoch 43/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1823 - accuracy: 0.9326 - val_loss: 0.3848 - val_accuracy: 0.8622
# Epoch 44/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2046 - accuracy: 0.9202 - val_loss: 0.3685 - val_accuracy: 0.8660
# Epoch 45/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1820 - accuracy: 0.9272 - val_loss: 0.3461 - val_accuracy: 0.8684
# Epoch 46/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1816 - accuracy: 0.9275 - val_loss: 0.3574 - val_accuracy: 0.8665
# Epoch 47/50
# 134/134 [==============================] - 33s 247ms/step - loss: 0.1823 - accuracy: 0.9143 - val_loss: 0.3487 - val_accuracy: 0.8627
# Epoch 48/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1697 - accuracy: 0.9322 - val_loss: 0.3727 - val_accuracy: 0.8542
# Epoch 49/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1883 - accuracy: 0.9259 - val_loss: 0.3569 - val_accuracy: 0.8660
# Epoch 50/50
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1760 - accuracy: 0.9357 - val_loss: 0.3477 - val_accuracy: 0.8622
# Tuned VGG16 test accuracy: 0.8660714285714286

# %% [markdown]
# ##Comparisons

# %%
def load_tuned_models(preds, model_name):
  from keras.models import load_model

  current_model = load_model(os.path.join(MODELS_DIR,'baseline_'+model_name+'.h5'))
  
  model_preds = current_model.predict([test_data_baseline_RGB, test_data_no_baseline_RGB])

  for pred in model_preds:
    preds.append(pred[0])


#execute fine tuning in a secondary process to avoid RAM saturation
models = ["resnet_tuned", "vgg16_tuned"]
for model in models:
  preds = process_manager.list()
  p = multiprocessing.Process(target=load_tuned_models, args=(preds, model))
  p.start()
  p.join()

  preds = np.asarray(preds)

  show_confusion_matrix(metrics.confusion_matrix(collapsed_test_labels, np.rint(preds)))
  print("\nTuned " + model + " test accuracy: " + str(metrics.accuracy_score(collapsed_test_labels, np.rint(preds))))

  fine_tuned_models_preds.update({model: preds})
# Out:
# Tuned resnet_tuned test accuracy: 0.8333333333333334
# Tuned vgg16_tuned test accuracy: 0.8660714285714286

# %%
show_roc_curves(fine_tuned_models_preds)
